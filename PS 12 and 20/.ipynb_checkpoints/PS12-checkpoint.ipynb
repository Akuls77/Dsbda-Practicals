# %% [raw]
# Scan the Iris dataset and give the inference as:
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# 3. Create a boxplot for each feature in the dataset.
# 4. Compare distributions and identify outliers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
sns.histplot(data=df, x='sepal_width')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=df, x='sepal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df, x='petal_width')
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data=df, x='petal_length')
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.boxplot(data=df, x='sepal_width', y='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='species'>

# %%
sns.boxplot(data=df, x='sepal_length', y='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.boxplot(data=df, x='petal_width', y='species')
# Out:
# <Axes: xlabel='petal_width', ylabel='species'>

# %%
sns.boxplot(data=df, x='petal_length', y='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
def detect_outlier(data):
    data = sorted(data)
    outlier = []
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1
    lb = q1 - 1.5*iqr
    ub = q3 + 1.5*iqr
    for i in data:
        if (i<lb or i>ub):
            outlier.append(i)
    return outlier, lb, ub

# %%
detect_outlier(df['sepal_width'])
# Out:
# ([2.0, 4.1, 4.2, 4.4], np.float64(2.05), np.float64(4.05))

# %%
sns.boxplot(data = df, x='sepal_width')
# Out:
# <Axes: xlabel='sepal_width'>

# %%
q1 = np.percentile(df['sepal_width'], 25)
q3 = np.percentile(df['sepal_width'], 75)
iqr = q3 - q1
lb = q1 - 1.5*iqr
ub = q3 + 1.5*iqr

df['sepal_width'] = df['sepal_width'].apply(lambda x: lb if x<=lb else ub if x>=ub else x)

# %%
detect_outlier(df['sepal_width'])
# Out:
# ([], np.float64(2.05), np.float64(4.05))

# %%
sns.boxplot(data = df, x='sepal_width')
# Out:
# <Axes: xlabel='sepal_width'>

# %%
detect_outlier(df['sepal_length'])
# Out:
# ([], np.float64(3.1499999999999986), np.float64(8.350000000000001))

# %%
detect_outlier(df['petal_width'])
# Out:
# ([], np.float64(-1.95), np.float64(4.05))

# %%
detect_outlier(df['petal_length'])
# Out:
# ([], np.float64(-3.649999999999999), np.float64(10.349999999999998))

# %%
sns.histplot(data=df, x='sepal_width', hue='species', kde=True, multiple='dodge')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=df, x='sepal_length', hue='species', kde=True, multiple='dodge')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=df, x='petal_width', hue='species', kde=True, multiple='dodge')
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data=df, x='petal_length', hue='species', kde=True, multiple='dodge')
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>
